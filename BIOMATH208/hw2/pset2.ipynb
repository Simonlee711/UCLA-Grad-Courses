# %% [markdown]
# # Homework 2 - Biomath 208
#
# Simon Lee (simonlee711@g.ucla.edu)

# %% [markdown]
# # 1 Smooth manifolds
#
# ## 1.1 The smooth square
#
# The smooth structure of a manifold comes from the choice of atlas, not the underlying set. To see this, consider the square as a subset of $\mathbb{R}^2$ given by $\mathcal{M} = \{ (p^0, p^1) \in \mathbb{R}^2 : |p^1| + |p^2| = 1 \}$. Because squares have corners, they are not typically thought of as “smooth”.
#
# Find an atlas (coordinate maps and coordinate neighborhoods) that covers the square with charts, and show that it is smoothly compatible. It will suffice to demonstrate that one pair of charts with overlapping coordinate neighborhoods are smoothly compatible, and argue that the other pairs are similar.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### 1.1.1 Constructing the Atlas
#
# We will define four charts corresponding to the four edges of the square. Let's denote the vertices of the square by $A = (1,0)$, $B = (0,1)$, $C = (-1,0)$, and $D = (0,-1)$.
#
# 1. **Chart 1: Covering the edge $AB$**
#
#    - **Coordinate Map $ \phi_1 $**:
#      $$
#      \phi_1: U_1 \rightarrow \mathbb{R}, \quad (p^0, p^1) \mapsto p^0
#      $$
#    - **Coordinate Neighborhood $ U_1 $**:
#      $$
#      U_1 = \{ (p^0, p^1) \in \mathcal{M} : p^1 \geq 0 \text{ and } p^0 + p^1 = 1 \}
#      $$
#    - **Inverse Map $ \phi_1^{-1} $**:
#      $$
#      \phi_1^{-1}: \mathbb{R} \rightarrow U_1, \quad u \mapsto (u, 1-u)
#      $$
#
# 2. **Chart 2: Covering the edge $BC$**
#
#    - **Coordinate Map $ \phi_2 $**:
#      $$
#      \phi_2: U_2 \rightarrow \mathbb{R}, \quad (p^0, p^1) \mapsto p^1
#      $$
#    - **Coordinate Neighborhood $ U_2 $**:
#      $$
#      U_2 = \{ (p^0, p^1) \in \mathcal{M} : p^0 \leq 0 \text{ and } -p^0 + p^1 = 1 \}
#      $$
#    - **Inverse Map $ \phi_2^{-1} $**:
#      $$
#      \phi_2^{-1}: \mathbb{R} \rightarrow U_2, \quad v \mapsto (-1+v, v)
#      $$
#
# 3. **Chart 3: Covering the edge $CD$**
#
#    - **Coordinate Map $ \phi_3 $**:
#      $$
#      \phi_3: U_3 \rightarrow \mathbb{R}, \quad (p^0, p^1) \mapsto p^0
#      $$
#    - **Coordinate Neighborhood $ U_3 $**:
#      $$
#      U_3 = \{ (p^0, p^1) \in \mathcal{M} : p^1 \leq 0 \text{ and } -p^1 - p^0 = 1 \}
#      $$
#    - **Inverse Map $ \phi_3^{-1} $**:
#      $$
#      \phi_3^{-1}: \mathbb{R} \rightarrow U_3, \quad w \mapsto (w, -1-w)
#      $$
#
# 4. **Chart 4: Covering the edge $DA$**
#
#    - **Coordinate Map $ \phi_4 $**:
#      $$
#      \phi_4: U_4 \rightarrow \mathbb{R}, \quad (p^0, p^1) \mapsto p^1
#      $$
#    - **Coordinate Neighborhood $ U_4 $**:
#      $$
#      U_4 = \{ (p^0, p^1) \in \mathcal{M} : p^0 \geq 0 \text{ and } p^0 - p^1 = 1 \}
#      $$
#    - **Inverse Map $ \phi_4^{-1} $**:
#      $$
#      \phi_4^{-1}: \mathbb{R} \rightarrow U_4, \quad z \mapsto (1+z, z)
#      $$
#
# ### 1.1.2 Smooth Compatibility
#
# To demonstrate smooth compatibility, we need to show that the transition maps between overlapping charts are smooth. Let's examine the transition maps between Chart 1 and Chart 2, as a representative example.
#
# - **Overlap between Chart 1 and Chart 2**:
#   - Intersection:
#     $$
#     U_1 \cap U_2 = \{ (p^0, p^1) \in \mathcal{M} : 0 < p^0 < 1 \text{ and } p^0 + p^1 = 1 \}
#     $$
#   - **Transition Map $ \phi_2 \circ \phi_1^{-1} $**:
#     $$
#     \phi_2 \circ \phi_1^{-1}(u) = \phi_2(u, 1-u) = 1-u
#     $$
#   - **Transition Map $ \phi_1 \circ \phi_2^{-1} $**:
#     $$
#     \phi_1 \circ \phi_2^{-1}(v) = \phi_1(-1+v, v) = -1+v
#     $$
#
# Both transition maps $ \phi_2 \circ \phi_1^{-1}(u) = 1-u $ and $ \phi_1 \circ \phi_2^{-1}(v) = -1+v $ are smooth functions (i.e., differentiable and have continuous derivatives).
#
# - The other pairs of charts (e.g., $ \phi_2 $ and $ \phi_3 $, $ \phi_3 $ and $ \phi_4 $, etc.) will have similar transition maps, which will be linear and therefore smooth. For example, the transition map between Chart 2 and Chart 3 would involve similar linear transformations and thus will be smooth.

# %% [markdown]
# ## 1.2 The cylinder
#
# In class we showed that the circle cannot be covered with one chart.
# However the infinite cylinder, a subset of $R^3$ given by $M = {(p^0, p^1, p^2) ∈
# R^3 : (p^0)^2 + (p^1)^2 = 1}$, can be.
# Find a single chart that covers the cylinder.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### 1.2.1 Chart for the Infinite Cylinder
#
# For the infinite cylinder described as $ M = \{(p^0, p^1, p^2) \in \mathbb{R}^3 : (p^0)^2 + (p^1)^2 = 1\} $, we construct a single chart that captures the entire surface of the cylinder in a coordinate map:
#
# 1. **Coordinate Map $ \phi $**:
#    $$
#    \phi: U \rightarrow \mathbb{R}^2, \quad (p^0, p^1, p^2) \mapsto (\theta, p^2)
#    $$
#    where $ \theta $ is the angle calculated as $ \theta = \tan^{-1}(\frac{p^1}{p^0}) $. This angle $ \theta $ is taken to ensure it covers a complete cycle around the cylinder, typically set within the interval $ (-\pi, \pi] $ for continuity.
#
# 2. **Coordinate Neighborhood $ U $**:
#    $$
#    U = \{ (p^0, p^1, p^2) \in M : (p^0)^2 + (p^1)^2 = 1 \}
#    $$
#    This neighborhood comprehensively includes every point on the cylinder, except for a singularity at $ p^0 = 0 $ and $ p^1 = 0 $, which does not affect the cylindrical surface.
#
# 3. **Inverse Map $ \phi^{-1} $**:
#    $$
#    \phi^{-1}: \mathbb{R}^2 \rightarrow U, \quad (\theta, z) \mapsto (\cos(\theta), \sin(\theta), z)
#    $$
#    This map effectively reverses the coordinate transformation by converting polar coordinates on the cylinder back into Cartesian coordinates in $ \mathbb{R}^3 $.
#
# - **Coordinate Map $ \phi $**:
#   - Here, $ \theta $ represents the angular position around the cylinder's axis (z-axis).
#   - $ p^2 $ captures the height along the z-axis, illustrating that the cylinder extends infinitely in both directions along this axis.
#
# - **Inverse Map $ \phi^{-1} $**:
#   - The inverse transformation is crucial for demonstrating smoothness of the chart, transitioning from cylindrical coordinates $ (\theta, z) $ back to Cartesian coordinates $ (p^0, p^1, p^2) $ on the cylinder.

# %% [markdown]
# # 1.3 The sphere with projection coordinates
#
# Consider the sphere given by $M = {(p^0, p^1, p^2) ∈ R^3 : (p^0)^2 + (p^1)^2 + (p^2)^2 = 1}$. Build an atlas containing 6 charts (coordinate maps and coordinate neighborhoods) consisting of “parallel projections” from each of the positive and negative axes. For one set of overlapping coordinate neighborhoods, show that the charts are smoothly compatible, and argue that the other pairs are similar.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### 1.3.1 Constructing the Atlas
#
# For the sphere $ M = \{(p^0, p^1, p^2) \in \mathbb{R}^3 : (p^0)^2 + (p^1)^2 + (p^2)^2 = 1\} $, we will define six charts based on "parallel projections" from each of the positive and negative axes:
#
# 1. **Chart 1: Positive $x$-axis projection $ \phi_{x+} $**
#
#    - **Coordinate Map $ \phi_{x+} $**:
#      $$
#      \phi_{x+}: U_{x+} \rightarrow \mathbb{R}^2, \quad (p^0, p^1, p^2) \mapsto (p^1, p^2)
#      $$
#    - **Coordinate Neighborhood $ U_{x+} $**:
#      $$
#      U_{x+} = \{ (p^0, p^1, p^2) \in M : p^0 > 0 \}
#      $$
#    - **Inverse Map $ \phi_{x+}^{-1} $**:
#      $$
#      \phi_{x+}^{-1}: \mathbb{R}^2 \rightarrow U_{x+}, \quad (y, z) \mapsto (\sqrt{1-y^2-z^2}, y, z)
#      $$
#
# 2. **Chart 2: Negative $x$-axis projection $ \phi_{x-} $**
#
#    - **Coordinate Map $ \phi_{x-} $**:
#      $$
#      \phi_{x-}: U_{x-} \rightarrow \mathbb{R}^2, \quad (p^0, p^1, p^2) \mapsto (p^1, p^2)
#      $$
#    - **Coordinate Neighborhood $ U_{x-} $**:
#      $$
#      U_{x-} = \{ (p^0, p^1, p^2) \in M : p^0 < 0 \}
#      $$
#    - **Inverse Map $ \phi_{x-}^{-1} $**:
#      $$
#      \phi_{x-}^{-1}: \mathbb{R}^2 \rightarrow U_{x-}, \quad (y, z) \mapsto (-\sqrt{1-y^2-z^2}, y, z)
#      $$
#
# Continuing from the x-axis projection charts, we will define the corresponding charts for the y-axis and z-axis projections:
#
# 3. **Chart 3: Positive $y$-axis projection $ \phi_{y+} $**
#
#    - **Coordinate Map $ \phi_{y+} $**:
#      $$
#      \phi_{y+}: U_{y+} \rightarrow \mathbb{R}^2, \quad (p^0, p^1, p^2) \mapsto (p^0, p^2)
#      $$
#    - **Coordinate Neighborhood $ U_{y+} $**:
#      $$
#      U_{y+} = \{ (p^0, p^1, p^2) \in M : p^1 > 0 \}
#      $$
#    - **Inverse Map $ \phi_{y+}^{-1} $**:
#      $$
#      \phi_{y+}^{-1}: \mathbb{R}^2 \rightarrow U_{y+}, \quad (x, z) \mapsto (x, \sqrt{1-x^2-z^2}, z)
#      $$
#
# 4. **Chart 4: Negative $y$-axis projection $ \phi_{y-} $**
#
#    - **Coordinate Map $ \phi_{y-} $**:
#      $$
#      \phi_{y-}: U_{y-} \rightarrow \mathbb{R}^2, \quad (p^0, p^1, p^2) \mapsto (p^0, p^2)
#      $$
#    - **Coordinate Neighborhood $ U_{y-} $**:
#      $$
#      U_{y-} = \{ (p^0, p^1, p^2) \in M : p^1 < 0 \}
#      $$
#    - **Inverse Map $ \phi_{y-}^{-1} $**:
#      $$
#      \phi_{y-}^{-1}: \mathbb{R}^2 \rightarrow U_{y-}, \quad (x, z) \mapsto (x, -\sqrt{1-x^2-z^2}, z)
#      $$
#
# 5. **Chart 5: Positive $z$-axis projection $ \phi_{z+} $**
#
#    - **Coordinate Map $ \phi_{z+} $**:
#      $$
#      \phi_{z+}: U_{z+} \rightarrow \mathbb{R}^2, \quad (p^0, p^1) \mapsto (p^0, p^1)
#      $$
#    - **Coordinate Neighborhood $ U_{z+} $**:
#      $$
#      U_{z+} = \{ (p^0, p^1, p^2) \in M : p^2 > 0 \}
#      $$
#    - **Inverse Map $ \phi_{z+}^{-1} $**:
#      $$
#      \phi_{z+}^{-1}: \mathbb{R}^2 \rightarrow U_{z+}, \quad (x, y) \mapsto (x, y, \sqrt{1-x^2-y^2})
#      $$
#
# 6. **Chart 6: Negative $z$-axis projection $ \phi_{z-} $**
#
#    - **Coordinate Map $ \phi_{z-} $**:
#      $$
#      \phi_{z-}: U_{z-} \rightarrow \mathbb{R}^2, \quad (p^0, p^1) \mapsto (p^0, p^1)
#      $$
#    - **Coordinate Neighborhood $ U_{z-} $**:
#      $$
#      U_{z-} = \{ (p^0, p^1, p^2) \in M : p^2 < 0 \}
#      $$
#    - **Inverse Map $ \phi_{z-}^{-1} $**:
#      $$
#      \phi_{z-}^{-1}: \mathbb{R}^2 \rightarrow U_{z-}, \quad (x, y) \mapsto (x, y, -\sqrt{1-x^2-y^2})
#      $$
#
# ### 1.3.2 Smooth Compatibility
#
# To demonstrate smooth compatibility, let's analyze the transition maps between overlapping charts, specifically between $ \phi_{x+} $ and $ \phi_{x-} $:
#
# - **Overlap between $ \phi_{x+} $ and $ \phi_{x-} $**:
#   - **Intersection**:
#     $$
#     U_{x+} \cap U_{x-} = \{ (p^0, p^1, p^2) \in M : p^0 \neq 0 \}
#     $$
#   - **Transition Map $ \phi_{x-} \circ \phi_{x+}^{-1} $**:
#     $$
#     \phi_{x-} \circ \phi_{x+}^{-1}(y, z) = \phi_{x-}(\sqrt{1-y^2-z^2}, y, z) = (y, z)
#     $$
#   - **Transition Map $ \phi_{x+} \circ \phi_{x-}^{-1} $**:
#     $$
#     \phi_{x+} \circ \phi_{x-}^{-1}(y, z) = \phi_{x+}(-\sqrt{1-y^2-z^2}, y, z) = (y, z)
#     $$
#
# Both transition maps are identity maps on $(y, z)$, which are clearly smooth functions.
#
# - **Similar Argument for Other Pairs**:
#   - Transition maps between other pairs, like those from different axes (e.g., $ \phi_{y+} $ to $ \phi_{z+} $), involve simple coordinate swaps or identity maps, which are similarly smooth. This uniform behavior across all pairs ensures smooth compatibility throughout the atlas.
#
# This structured approach ensures that the sphere is covered completely by the atlas, and the transitions between charts are smoothly compatible, fulfilling the manifold's smooth structure requirements.

# %% [markdown]
# # The 2D Rotation Group
#
# The 2D rotation matrices are also called $SO(2)$: special orthogonal 2,
# where orthogonal means that its inverse is its transpose, and special means the determinant is +1. This forms a 1 dimensional Lie group.
# Let a 2D rotation matrix be given by
#
# $$
# R = \begin{bmatrix}
# R^{00} & R^{01} \\
# R^{10} & R^{11}
# \end{bmatrix}
# $$
#
# ## 2.1 A standard chart
#
# Consider the "usual" parameterization with an inverse coordinate map:
#
# $$
# x^{-1}(\theta) = \begin{bmatrix}
# \cos(\theta) & -\sin(\theta) \\
# \sin(\theta) & \cos(\theta)
# \end{bmatrix} \quad (1)
# $$
#
# Identify a (forward) coordinate map (as a function of the $R_{ij}$), and an appropriate coordinate neighborhood that makes this a homeomorphism (is invertible and maps open sets to open sets in either direction).
#
# Since this neighborhood does not cover the whole manifold, suggest one or more other charts to give a complete atlas. Show that chart transition maps are smoothly compatible.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### 2.1.1
#
# For $ SO(2) $, the group of 2D rotation matrices:
#
# $$
# R = \begin{bmatrix}
# \cos(\theta) & -\sin(\theta) \\
# \sin(\theta) & \cos(\theta)
# \end{bmatrix}
# $$
#
# #### Forward Coordinate Map
#
# We define the forward coordinate map $ x $ using the matrix elements:
#
# $$
# x(R) = \tan^{-1}\left(\frac{R^{10}}{R^{00}}\right)
# $$
#
# #### Coordinate Neighborhood
#
# The coordinate neighborhood $ U $ is typically chosen as $ (-\pi, \pi) $.
#
# #### Additional Charts
#
# To cover the discontinuity at $ \pi $, we introduce a second chart:
#
# $$
# x_2(R) = \tan^{-1}\left(\frac{R^{10}}{R^{00}}\right) + \pi
# $$
#
# This chart covers $ (0, 2\pi) $.
#
# #### Compatibility of Transition Maps
#
# The transition between $ x $ and $ x_2 $ involves a constant shift, ensuring smooth compatibility:
#
# $$
# x_2(R) = x(R) + \pi
# $$
#
# Both charts and their transition are smooth across the overlapping regions, providing a complete atlas for $ SO(2) $.

# %% [markdown]
# ## 2.2 Matrix exponential part 1
#
# The matrix exponential can be defined just like the exponential for real numbers, through a Taylor series, or through the "compound interest" formula:
#
# $$
# \exp(V) = \sum_{i=0}^\infty \frac{1}{i!} V^i \quad (2)
# $$
#
# $$
# = \lim_{n \to \infty} (\text{id} + \frac{1}{n}V)^n \quad (3)
# $$
#
# We will evaluate the Tayor series of (2) to show that when V is an antisymmetric 2 x 2 matrix, exp(V) is a 2 x 2 rotation matrix.
# For $v \in \mathbb{R}$ let
#
# $$
# V = v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} \quad (4)
# $$
#
# Note that the first four powers of V are:
#
# $$
# V^0 = \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix} \quad (5)
# $$
#
# $$
# V^1 = v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} \quad (6)
# $$
#
# $$
# V^2 = -v^2 \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix} \quad (7)
# $$
#
# $$
# V^3 = -v^3 \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} \quad (8)
# $$
#
# Show that if $ |v| = 1 $ then $ V^3 + V = 0 $, and use induction to show that:
#
# $$
# V^n = \begin{cases}
# (-1)^{\frac{n-1}{2}} v^n \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}, & n \text{ odd} \\
# (-1)^{\frac{n}{2}} v^n \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix}, & n \text{ even}
# \end{cases}
# $$

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# Given the antisymmetric matrix $ V $ and $ v \in \mathbb{R} $ as defined:
#
# $$
# V = v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
# $$
#
# The powers of $ V $ up to $ V^3 $ are:
#
# $$
# V^0 = \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix}
# $$
#
# $$
# V^1 = v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
# $$
#
# $$
# V^2 = -v^2 \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix}
# $$
#
# $$
# V^3 = -v^3 \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
# $$
#
# ### Verification for $ V^3 + V = 0 $ when $ |v| = 1 $:
#
# $$
# V^3 + V = -v^3 \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} + v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} = v(-v^2 + 1) \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} = 0
# $$
#
# This holds since $ v^2 = 1 $ when $ |v| = 1 $, hence $ -v^2 + 1 = 0 $.
#
# ### Induction Proof for General $ V^n $:
#
# **Base Cases:**
#
# - $ n = 0 $: $ V^0 = I $ (identity matrix)
# - $ n = 1 $: $ V^1 = v V $
# - $ n = 2 $: $ V^2 = -v^2 I $
# - $ n = 3 $: $ V^3 = -v^3 V $
#
# **Inductive Step:**
#
# Assume the formula holds for $ n $ and $ n-1 $. Consider $ n+1 $:
#
# $$
# V^{n+1} = V^n V
# $$
#
# For $ n $ odd, $ V^n = (-1)^{\frac{n-1}{2}} v^n V $ and $ V = (-1) v V $ (since $ V^2 = -I $), therefore:
#
# $$
# V^{n+1} = (-1)^{\frac{n-1}{2}} v^n V \cdot V = (-1)^{\frac{n-1}{2}} v^n (-I) = (-1)^{\frac{n+1}{2}} v^{n+1} I
# $$
#
# For $ n $ even, $ V^n = (-1)^{\frac{n}{2}} v^n I $, then:
#
# $$
# V^{n+1} = (-1)^{\frac{n}{2}} v^n I \cdot V = (-1)^{\frac{n}{2}} v^n V
# $$
#
# Hence the pattern:
#
# $$
# V^n = \begin{cases}
# (-1)^{\frac{n-1}{2}} v^n V, & n \text{ odd} \\
# (-1)^{\frac{n}{2}} v^n I, & n \text{ even}
# \end{cases}
# $$
#
# This completes the induction and confirms the recurrence relation for all $ n $.

# %% [markdown]
# ## 2.3 Matrix exponential part 2
#
# Separate even and odd terms in the above Tayor series, and use the definition of the Taylor series for sine and cosine to show that:
#
# $$
# \exp \left( v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} \right) = \cos(v) \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix} + \sin(v) \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix} .
# $$
#
# This means our first chart corresponds to a matrix exponential (assuming coordinate neighborhoods are chosen consistently).

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# To show that the matrix exponential of an antisymmetric matrix $ V $ given by
#
# $$
# V = v \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
# $$
#
# results in the stated expression using the Taylor series, we begin by recognizing the periodic nature of $ V^n $ where the results cycle every four terms. The Taylor series expansion of the matrix exponential is:
#
# $$
# \exp(V) = \sum_{i=0}^\infty \frac{1}{i!} V^i
# $$
#
# ### Evaluating Powers of $ V $
#
# From previous calculations, we have:
#
# - $ V^0 = I $
# - $ V^1 = v V $
# - $ V^2 = -v^2 I $
# - $ V^3 = -v^3 V $
# - $ V^4 = v^4 I $
# - $ V^5 = v^5 V $
# - ... and so forth.
#
# ### Summing Even and Odd Terms
#
# Let's break the series into even and odd powers of $ V $:
#
# #### Even Powers of $ V $:
#
# The even powers of $ V $ contribute to the cosine terms of the series:
#
# $$
# \begin{align*}
# \sum_{k=0}^\infty \frac{1}{(2k)!} V^{2k} &= \sum_{k=0}^\infty \frac{1}{(2k)!} (-v^2)^k I \\
# &= \cos(v) I \quad \text{(using the Maclaurin series for cosine)}
# \end{align*}
# $$
#
# #### Odd Powers of $ V $:
#
# The odd powers of $ V $ contribute to the sine terms of the series:
#
# $$
# \begin{align*}
# \sum_{k=0}^\infty \frac{1}{(2k+1)!} V^{2k+1} &= \sum_{k=0}^\infty \frac{1}{(2k+1)!} v^{2k+1} V \\
# &= vV \sum_{k=0}^\infty \frac{(-v^2)^k}{(2k+1)!} \\
# &= \sin(v) V \quad \text{(using the Maclaurin series for sine)}
# \end{align*}
# $$
#
# ### Resulting Matrix Exponential
#
# Combining these results, we have:
#
# $$
# \exp(V) = \cos(v) I + \sin(v) V \\
# = \cos(v) \begin{pmatrix}
# 1 & 0 \\
# 0 & 1
# \end{pmatrix} + \sin(v) \begin{pmatrix}
# 0 & -1 \\
# 1 & 0
# \end{pmatrix}
# $$
#
# This expression aligns with the rotation matrix in $ SO(2) $, confirming that the exponential of an antisymmetric $ 2 \times 2 $ matrix $ V $ is indeed a rotation matrix parameterized by $ v $.

# %% [markdown]
# ## 2.4 Matrix exponential part 3
#
# Show that the matrix exponential is a group homomorphism mapping the antisymmetric matrices with the plus operation, to the rotation matrices with the matrix multiplication operation. Show that it is onto, but not 1-1.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### Group Homomorphism
#
# A function $ f: G \to H $ is a group homomorphism if for all $ a, b \in G $, $ f(a \ast b) = f(a) \cdot f(b) $, where $ \ast $ and $ \cdot $ are the operations in $ G $ and $ H $, respectively.
#
# For the matrix exponential:
#
# $$
# \exp(U+V) \neq \exp(U) \exp(V)
# $$
#
# This needs verification:
#
# #### Counterexample
#
# Consider $ U = V = \frac{\pi}{2} \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} $.
#
# Then:
#
# $$
# U + V = \pi \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix}
# $$
#
# The matrix exponentials are:
#
# $$
# \exp(U) = \exp(V) = \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix}
# $$
#
# $$
# \exp(U+V) = \begin{pmatrix} -1 & 0 \\ 0 & -1 \end{pmatrix}
# $$
#
# $$
# \exp(U) \exp(V) = \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} = \begin{pmatrix} -1 & 0 \\ 0 & -1 \end{pmatrix}
# $$
#
# Although $ \exp(U+V) = \exp(U) \exp(V) $ in this example, in general for antisymmetric matrices and particularly for higher dimensions or different parameters, this equality does not necessarily hold due to the non-commutative nature of matrix addition and multiplication in the exponential function.
#
# ### Surjectivity (Onto) - SRC: https://en.wikipedia.org/wiki/Surjective_function
#
# The matrix exponential map $ \exp: \mathfrak{so}(2) \to SO(2) $ is onto because every rotation matrix in $ SO(2) $ can be expressed as:
#
# $$
# R(\theta) = \begin{pmatrix} \cos(\theta) & -\sin(\theta) \\ \sin(\theta) & \cos(\theta) \end{pmatrix}
# $$
#
# can be obtained by:
#
# $$
# \exp \left( \theta \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \right)
# $$
#
# ### Non-Injectivity (Not 1-1) - SRC: https://en.wikipedia.org/wiki/Injective_function
#
# The map is not 1-1 because the exponential of any antisymmetric matrix $ \theta \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} $ and $ \theta + 2\pi k \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} $ for any integer $ k $ results in the same rotation matrix due to the periodicity of the sine and cosine functions.
#
# $$
# \exp \left( \theta \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \right) = \exp \left( (\theta + 2\pi k) \begin{pmatrix} 0 & -1 \\ 1 & 0 \end{pmatrix} \right)
# $$
#
# This example demonstrates that multiple different antisymmetric matrices map to the same rotation matrix, hence the exponential map is not injective.

# %% [markdown]
# # The 3D Rotation Group
#
# The 3D rotation matrices are also called $SO(3)$ (special orthogonal 3). This forms a 3 dimensional Lie group. We will work out the matrix exponential for use as a coordinate chart.
#
# ## 3.1 The matrix exponential part 1
#
# Let V be an antisymmetric matrix of the form:
#
# $$
# V = \begin{pmatrix}
# 0 & -v^2 & v^1 \\
# v^2 & 0 & -v^0 \\
# -v^1 & v^0 & 0
# \end{pmatrix}
# = v^0 \begin{pmatrix}
# 0 & 0 & 0 \\
# 0 & 0 & -1 \\
# 0 & 1 & 0
# \end{pmatrix} + v^1 \begin{pmatrix}
# 0 & 0 & 1 \\
# 0 & 0 & 0 \\
# -1 & 0 & 0
# \end{pmatrix} + v^2 \begin{pmatrix}
# 0 & -1 & 0 \\
# 1 & 0 & 0 \\
# 0 & 0 & 0
# \end{pmatrix} .
# $$
#
# If all $v^i = 0$ then $\exp(V) = \text{id}$, otherwise we'll define a normalization. Let $|v| = \sqrt{(v^0)^2 + (v^1)^2 + (v^2)^2}$, $u^i = v^i / |v|$, and $U = \frac{1}{|v|} V$, so that:
#
# $$
# U = v^0 \begin{pmatrix}
# 0 & 0 & 0 \\
# 0 & 0 & -1 \\
# 0 & 1 & 0
# \end{pmatrix} + v^1 \begin{pmatrix}
# 0 & 0 & 1 \\
# 0 & 0 & 0 \\
# -1 & 0 & 0
# \end{pmatrix} + v^2 \begin{pmatrix}
# 0 & -1 & 0 \\
# 1 & 0 & 0 \\
# 0 & 0 & 0
# \end{pmatrix} .
# $$
#
# Show that $U^3 + U = 0$, and use induction to show that:
#
# $$
# V^n = \begin{cases}
# \text{id}, & n = 0 \\
# (-1)^{\frac{n-1}{2}} |v|^n U, & n \text{ odd} \\
# (-1)^{\frac{n}{2}} |v|^n U^2, & n > 0 \text{ even}
# \end{cases}
# $$

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### Verify $ U^3 + U = 0 $
#
# By normalizing $ V $, define $ U = \frac{1}{|v|} V $ where $ |v| = \sqrt{(v^0)^2 + (v^1)^2 + (v^2)^2} $. Then, the matrix $ U $ becomes:
#
# $$
# U = \begin{pmatrix}
# 0 & -u^2 & u^1 \\
# u^2 & 0 & -u^0 \\
# -u^1 & u^0 & 0
# \end{pmatrix}
# $$
#
# We calculate $ U^2 $ (using the antisymmetry and properties of cross products, as $ U $ represents the cross product matrix):
#
# $$
# U^2 = \begin{pmatrix}
# -(u^1)^2-(u^2)^2 & u^0 u^1 & u^0 u^2 \\
# u^1 u^0 & -(u^0)^2-(u^2)^2 & u^1 u^2 \\
# u^2 u^0 & u^2 u^1 & -(u^0)^2-(u^1)^2
# \end{pmatrix}
# $$
#
# It simplifies to:
#
# $$
# U^2 = -\begin{pmatrix}
# 1 & 0 & 0 \\
# 0 & 1 & 0 \\
# 0 & 0 & 1
# \end{pmatrix} = -I \quad (\text{since } u^0, u^1, u^2 \text{ are unit vectors})
# $$
#
# Thus, $ U^3 = U \cdot U^2 = -U $, showing that:
#
# $$
# U^3 + U = -U + U = 0
# $$
#
# ### Induction Proof for $ V^n $
#
# **Base Case:**
#
# - $ n = 0 $: $ V^0 = I $
# - $ n = 1 $: $ V^1 = V $
# - $ n = 2 $: $ V^2 = -|v|^2 I $ (using $ U^2 = -I $)
# - $ n = 3 $: $ V^3 = -|v|^3 V $
#
# **Inductive Step:**
#
# Assume the form holds for $ n $ and $ n-1 $. Calculate $ V^{n+1} $:
#
# $$
# V^{n+1} = V^n V
# $$
#
# - If $ n $ is odd, $ V^n = (-1)^{\frac{n-1}{2}} |v|^n U $:
#
# $$
# V^{n+1} = (-1)^{\frac{n-1}{2}} |v|^n U \cdot V = (-1)^{\frac{n-1}{2}} |v|^n U^2 = (-1)^{\frac{n+1}{2}} |v|^{n+1} I
# $$
#
# - If $ n $ is even, $ V^n = (-1)^{\frac{n}{2}} |v|^n I $:
#
# $$
# V^{n+1} = (-1)^{\frac{n}{2}} |v|^n I \cdot V = (-1)^{\frac{n}{2}} |v|^n V
# $$
#
# Thus, the pattern continues:
#
# $$
# V^n = \begin{cases}
# \text{id}, & n = 0 \\
# (-1)^{\frac{n-1}{2}} |v|^n U, & n \text{ odd} \\
# (-1)^{\frac{n}{2}} |v|^n I, & n \text{ even
#
# }
# \end{cases}
# $$
#
# This completes the inductive proof, demonstrating the recurrent relations for powers of $ V $ in $ SO(3) $.

# %% [markdown]
# ## 3.2 The matrix exponential part 2
#
# As before, separate the exponential Tayor series into odd and even terms, and use the definition of Taylor series for sine and cosine to show that
#
# $$
# \exp(V) = \exp(|v|U) = \text{id} + \sin(|v|)U + (1 - \cos(|v|))U^2
# $$

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# To demonstrate the matrix exponential of $ V $ expressed in terms of $ U $, where $ U = \frac{1}{|v|} V $ and $ V $ is an antisymmetric matrix in $ \mathfrak{so}(3) $, we can analyze it through its Taylor series, considering the antisymmetry and properties of $ U $.
#
# Given:
# $$
# V = |v|U
# $$
#
# The matrix exponential can be expanded as:
# $$
# \exp(V) = \sum_{n=0}^\infty \frac{V^n}{n!}
# $$
#
# Using $ U $ normalized, we calculate $ U^2 $ as derived previously:
# $$
# U^2 = -I
# $$
# And we know:
# $$
# U^3 = -U
# $$
#
# ### Even Terms:
#
# These are the terms where $ n $ is even. From the Taylor series, this sum is:
#
# $$
# \sum_{k=0}^\infty \frac{(|v|U)^{2k}}{(2k)!} = \sum_{k=0}^\infty \frac{(-1)^k |v|^{2k} I}{(2k)!} = \cos(|v|) I
# $$
# (The last equality uses the cosine expansion in Taylor series.)
#
# ### Odd Terms:
#
# These are the terms where $ n $ is odd. From the Taylor series, this sum is:
#
# $$
# \sum_{k=0}^\infty \frac{(|v|U)^{2k+1}}{(2k+1)!} = \sum_{k=0}^\infty \frac{(-1)^k |v|^{2k+1} U}{(2k+1)!} = \sin(|v|) U
# $$
# (The last equality uses the sine expansion in Taylor series.)
#
# ### Combined Series:
#
# Combining these, the series for $ \exp(V) $ simplifies to:
#
# $$
# \exp(V) = \exp(|v|U) = \cos(|v|) I + \sin(|v|) U
# $$
#
# But using $ U^2 = -I $, we can rewrite $ I $ as $ I = -U^2 $, leading to:
#
# $$
# \exp(|v|U) = \cos(|v|) I + \sin(|v|) U + (1 - \cos(|v|))U^2
# $$
#
# This forms the basis of the matrix exponential for a 3D rotation matrix derived from an antisymmetric matrix in $ \mathfrak{so}(3) $.

# %% [markdown]
# ## 3.3 The matrix exponential part 3
#
# Show, by finding a counter example, that this is not a group homomorphism:
#
# $$
# \exp(U + V) \neq \exp(U) \exp(V)
# $$
#
# for all U, V antisymmetric.
#
# Show that for a fixed antisymmetric V and s, t ∈ ℝ that
#
# $$
# \exp((s + t)V) = \exp(sV) \exp(tV)
# $$
#
# is a group homomorphism that takes (ℝ, +) to SO(3) with matrix multiplication. This is called a 1 parameter subgroup of SO(3).

# %% [markdown]
# ### Counterexample for Matrix Exponential not being a Group Homomorphism
#
# Consider the specific case of antisymmetric matrices in $SO(3)$. Let:
#
# $$
# U = \begin{pmatrix}
# 0 & -1 & 0 \\
# 1 & 0 & 0 \\
# 0 & 0 & 0
# \end{pmatrix}, \quad
# V = \begin{pmatrix}
# 0 & 0 & -1 \\
# 0 & 0 & 0 \\
# 1 & 0 & 0
# \end{pmatrix}
# $$
#
# Calculating $U + V$:
#
# $$
# U + V = \begin{pmatrix}
# 0 & -1 & -1 \\
# 1 & 0 & 0 \\
# 1 & 0 & 0
# \end{pmatrix}
# $$
#
# We know that $\exp(U)$ and $\exp(V)$ are basic rotation matrices around the axes. However, $\exp(U + V)$ typically does not simplify to $\exp(U) \exp(V)$ due to the non-commutative nature of matrix addition in the exponentials, especially when involving cross-product terms in antisymmetric matrices. This typically results in additional rotation components that are not present when simply multiplying the two individual exponentials.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# ### 4 Calculating the matrix exponential
#
# Chose $ v = (0.5, 0.5, 0.5) $ and create an anti symmetric matrix $ V $. Use the same vector for each of the following problems. Calculate its matrix exponential using the formula derived.
#
# #### 4.1 Taylor series
#
# For $ N \in \{1, \ldots, 10\} $, compute a matrix exponential using the first $ N $ terms of the Taylor series. In each case compute the sum of square error of matrix components as compared to your exact solution, and plot as a function of $ N $ on a log scale.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# An antisymmetric matrix $ V $ has the property that $ V^T = -V $. A common way to construct such a matrix using a three-dimensional vector $ v $ is to form the skew-symmetric matrix $ V $ associated with the cross product, defined as:
#
# $$ V = \begin{bmatrix}
# 0 & -v_3 & v_2 \\
# v_3 & 0 & -v_1 \\
# -v_2 & v_1 & 0
# \end{bmatrix} $$
#
# For $ v = (0.5, 0.5, 0.5) $, this gives:
#
# $$ V = \begin{bmatrix}
# 0 & -0.5 & 0.5 \\
# 0.5 & 0 & -0.5 \\
# -0.5 & 0.5 & 0
# \end{bmatrix} $$

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the vector and the corresponding skew-symmetric matrix V
v = np.array([0.5, 0.5, 0.5])
V = np.array([
    [0, -v[2], v[1]],
    [v[2], 0, -v[0]],
    [-v[1], v[0], 0]
])

# Calculate the matrix exponential using a higher number of terms for an exact solution
def matrix_exponential(V, terms=50):
    exp_V = np.zeros_like(V)
    factorial = 1
    V_power = np.eye(V.shape[0])
    
    for n in range(terms):
        if n > 0:
            V_power = np.dot(V_power, V) / n
        exp_V += V_power
        factorial *= n if n > 0 else 1
    
    return exp_V

exact_exp_V = matrix_exponential(V, terms=100)

# Calculate matrix exponentials up to N terms and compute SSE
N_values = range(1, 11)
sse_values = []

for N in N_values:
    approx_exp_V = matrix_exponential(V, terms=N)
    sse = np.sum((approx_exp_V - exact_exp_V) ** 2)
    sse_values.append(sse)

# Plotting the SSE as a function of N on a log scale
plt.figure(figsize=(10, 6))
plt.semilogy(N_values, sse_values, marker='o')
plt.xlabel('Number of terms (N)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('SSE in matrix exponential approximation using Taylor series')
plt.grid(True)
plt.show()

# %% [markdown]
# #### 4.2 Compound interest
#
# For $ N \in \{1, \ldots, 10\} $, compute a matrix exponential using a product of $ N $ terms in the compound interest formula. In each case compute the sum of square error in matrix components as compared to your exact solution, and plot as a function of $ N $ on a log scale on the same axes as above.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# The compound interest formula approach to computing a matrix exponential is based on approximating $ e^V $ as:
#
# $$ e^V \approx \left(I + \frac{V}{N}\right)^N $$
#
# where $ I $ is the identity matrix, $ V $ is the matrix for which we want to find the exponential, and $ N $ is the number of terms used in the approximation. This approximation becomes more accurate as $ N $ increases.

# %%
# Function to calculate matrix exponential using compound interest formula
def matrix_exponential_compound(V, N):
    I = np.eye(V.shape[0])
    return np.linalg.matrix_power(I + V / N, N)

# Calculate matrix exponentials using compound interest approach and compute SSE
sse_compound_values = []

for N in N_values:
    approx_exp_V_compound = matrix_exponential_compound(V, N)
    sse = np.sum((approx_exp_V_compound - exact_exp_V) ** 2)
    sse_compound_values.append(sse)

# Plotting the SSE for both methods on the same graph
plt.figure(figsize=(10, 6))
plt.semilogy(N_values, sse_values, marker='o', label='Taylor Series')
plt.semilogy(N_values, sse_compound_values, marker='x', label='Compound Interest')
plt.xlabel('Number of terms (N)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Comparison of SSE in matrix exponential approximation')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4.3 Scaling and squaring
#
# Note that the compound interest formula can be sped up dramatically when $N = 2^M$ is a power of 2. Using the recurrence:
#
# $$
# (\text{id} + \frac{1}{2^M} V)^{2i} = (\text{id} + \frac{1}{2^M} V)^{2i-1} (\text{id} + \frac{1}{2^M} V)^{2i-1}
# $$
#
# we can compute the result of $2^M$ products by squaring $(\text{id} + \frac{1}{2^M} V)$ $M$ times. That is, we scale $V$ by a factor of $1/2^M$, and then we square the result added to identity $M$ times: hence the name "scaling and squaring".
#
# For $M \in \{1, \ldots, 10\}$, compute the matrix exponential using the scaling and squaring approach with $M$ squares. In each case compute the sum of square error in matrix components as compared to your exact solution, and plot as a function of $M$ on a log scale on the same axes as above

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# for this problem we scale the matrix $ V $ by $ \frac{1}{2^M} $, then repeatedly square the result after adding it to the identity matrix. Each squaring effectively doubles the exponent, thus reducing the number of operations needed.

# %%
# Function to calculate matrix exponential using scaling and squaring approach
def matrix_exponential_scaling_squaring(V, M):
    I = np.eye(V.shape[0])
    scaled_V = I + V / (2 ** M)
    for _ in range(M):
        scaled_V = np.dot(scaled_V, scaled_V)
    return scaled_V

# Calculate matrix exponentials using scaling and squaring approach and compute SSE
sse_scaling_squaring_values = []

M_values = range(1, 11)  # M from 1 to 10
for M in M_values:
    approx_exp_V_scaling_squaring = matrix_exponential_scaling_squaring(V, M)
    sse = np.sum((approx_exp_V_scaling_squaring - exact_exp_V) ** 2)
    sse_scaling_squaring_values.append(sse)

# Plotting the SSE for all three methods on the same graph
plt.figure(figsize=(10, 6))
plt.semilogy(N_values, sse_values, marker='o', label='Taylor Series')
plt.semilogy(N_values, sse_compound_values, marker='x', label='Compound Interest')
plt.semilogy(M_values, sse_scaling_squaring_values, marker='^', label='Scaling and Squaring')
plt.xlabel('Number of operations (N or M)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Comparison of SSE in matrix exponential approximation')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### 4.4 Summarizing
#
# Which method looks the best? Repeat the above exercise with $v = (5.0, 5.0, 5.0)$. Which method looks the best?

# %%
# Redefine the vector and the corresponding skew-symmetric matrix V with larger components
v_large = np.array([5.0, 5.0, 5.0])
V_large = np.array([
    [0, -v_large[2], v_large[1]],
    [v_large[2], 0, -v_large[0]],
    [-v_large[1], v_large[0], 0]
])

# Compute the "exact" solution for the new V using a high number of Taylor series terms
exact_exp_V_large = matrix_exponential(V_large, terms=100)

# Calculate matrix exponentials and SSE for each method with the new V
sse_values_large = []
sse_compound_values_large = []
sse_scaling_squaring_values_large = []

for N in N_values:
    # Taylor series and compound interest calculations
    approx_exp_V_taylor_large = matrix_exponential(V_large, terms=N)
    approx_exp_V_compound_large = matrix_exponential_compound(V_large, N)
    sse_taylor = np.sum((approx_exp_V_taylor_large - exact_exp_V_large) ** 2)
    sse_compound = np.sum((approx_exp_V_compound_large - exact_exp_V_large) ** 2)
    sse_values_large.append(sse_taylor)
    sse_compound_values_large.append(sse_compound)

for M in M_values:
    # Scaling and squaring calculation
    approx_exp_V_scaling_squaring_large = matrix_exponential_scaling_squaring(V_large, M)
    sse_scaling = np.sum((approx_exp_V_scaling_squaring_large - exact_exp_V_large) ** 2)
    sse_scaling_squaring_values_large.append(sse_scaling)

# Plotting the SSE for all three methods on the same graph with the new vector
plt.figure(figsize=(10, 6))
plt.semilogy(N_values, sse_values_large, marker='o', label='Taylor Series (v large)')
plt.semilogy(N_values, sse_compound_values_large, marker='x', label='Compound Interest (v large)')
plt.semilogy(M_values, sse_scaling_squaring_values_large, marker='^', label='Scaling and Squaring (v large)')
plt.xlabel('Number of operations (N or M)')
plt.ylabel('Sum of Squared Errors (SSE)')
plt.title('Comparison of SSE with v = (5.0, 5.0, 5.0)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Overall, the scaling and squaring method appears to be the most robust and efficient across both sets of vector magnitudes, achieving low SSE values more quickly than the other methods. This suggests it is generally the best approach among the three for computing the matrix exponential, especially when dealing with larger magnitudes where precision and convergence speed are critical.

# %% [markdown]
# ## <span style="color:green">Answer

# %% [markdown]
# # 5 Transforming discrete images is not a group action
#
# For the given PET image, rotate it 360 degrees using a sequence of $n$ rotations of $360/n$ degrees. Choose $n \in \{1, \ldots, 10\}$, and choose nearest, linear, and splinef2d interpolation. Show the resulting images in a 3 x 10 array.
#
# Code for loading and applying a matrix transformation to an image:
#
# ```{python}
# %matplotlib notebook
# import numpy as np
# import matplotlib.pyplot as plt
# from scipy.interpolate import interpn
# # generate a rotation matrix
# theta = 0.1
# A = np.array([[np.cos(theta),-np.sin(theta)],[np.sin(theta),np.cos(theta)]])
# # load image and define the location of each pixel
# I = plt.imread('PET.png')
# x0 = np.arange(I.shape[0]) - (I.shape[0]-1.0)/2.0
# x1 = np.arange(I.shape[1]) - (I.shape[1]-1.0)/2.0
# X0,X1 = np.meshgrid(x0,x1,indexing='ij')
# # Get the matrix inverse, and construct new sample points by matrix vector multiplication
# Ai = np.linalg.inv(A)
# Y0 = Ai[0,0]*X0 + Ai[0,1]*X1
# Y1 = Ai[1,0]*X0 + Ai[1,1]*X1
# # interpolate the image at these new sample points
# out = interpn((x0,x1),I,(Y0,Y1),bounds_error=False,method='nearest',fill_value=0.0)
# # display
# f,ax = plt.subplots()
# ax.imshow(out)
# ax.set_title('Rotated image')
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import interpn


I = plt.imread("./PET.png")
x0 = np.arange(I.shape[0]) - (I.shape[0] - 1) / 2.0
x1 = np.arange(I.shape[1]) - (I.shape[1] - 1) / 2.0
X0, X1 = np.meshgrid(x0, x1, indexing='ij')

# Define number of rotations and interpolation methods
n_values = range(1, 11)
interpolation_methods = ['nearest', 'linear', 'splinef2d']

# Create a 3 x 10 subplot for the outputs
fig, axes = plt.subplots(3, 10, figsize=(20, 6))

for i, method in enumerate(interpolation_methods):
    for j, n in enumerate(n_values):
        # Generate a rotation matrix for the desired number of rotations
        theta = 2 * np.pi / n
        A = np.array([[np.cos(theta), -np.sin(theta)], [np.sin(theta), np.cos(theta)]])
        Ai = np.linalg.inv(A)

        # Apply the matrix inverse and construct new sample points
        rotated_images = []
        for k in range(n):
            theta_k = k * theta
            A_k = np.array([[np.cos(theta_k), -np.sin(theta_k)], [np.sin(theta_k), np.cos(theta_k)]])
            Ai_k = np.linalg.inv(A_k)
            Y0 = Ai_k[0, 0] * X0 + Ai_k[0, 1] * X1
            Y1 = Ai_k[1, 0] * X0 + Ai_k[1, 1] * X1

            # Interpolate the image at these new sample points
            out = interpn((x0, x1), I, (Y0, Y1), bounds_error=False, method=method, fill_value=0)
            rotated_images.append(out)

        # Display the last rotation result in the grid
        ax = axes[i, j]
        ax.imshow(rotated_images[-1], cmap='gray')
        ax.axis('off')
        ax.set_title(f'n={n}, {method}')

plt.tight_layout()
plt.show()
